# %%
# !git clone https://github.com/googlecodelabs/tensorflow-for-poets-2
# Out:
# Cloning into 'tensorflow-for-poets-2'...
# remote: Enumerating objects: 426, done.
# remote: Total 426 (delta 0), reused 0 (delta 0), pack-reused 426
# Receiving objects: 100% (426/426), 33.97 MiB | 34.75 MiB/s, done.
# Resolving deltas: 100% (159/159), done.

# %%
# !git clone https://github.com/SHvatov/PricesML
# Out:
# Cloning into 'PricesML'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 591 (delta 0), reused 0 (delta 0), pack-reused 588
# Receiving objects: 100% (591/591), 72.59 MiB | 36.05 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
# %cd tensorflow-for-poets-2/
# Out:
# /content/tensorflow-for-poets-2

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !python scripts/retrain.py --output_graph=tf_files/retrained_graph.pb --output_labels=tf_files/retrained_labels.txt --image_dir=/content/dataset/train
# Out:
# WARNING:tensorflow:From scripts/retrain.py:1326: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From scripts/retrain.py:970: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0409 19:42:24.812443 140149492332416 module_wrapper.py:139] From scripts/retrain.py:970: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From scripts/retrain.py:970: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W0409 19:42:24.812633 140149492332416 module_wrapper.py:139] From scripts/retrain.py:970: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From scripts/retrain.py:835: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# ...

# %%
# in case of errors try to modify /content/tensorflow-for-poets-2/scripts/label_image.py by setting following values in lines ~74-78:
# input_height = 299
# input_width = 299
# input_mean = 0
# input_layer = "Mul"

# !python scripts/label_image.py --image /content/PricesML/objects-detection/transfer_learning/ref-data/sample_images/Lemon_001.jpg
# Out:
# WARNING:tensorflow:From scripts/label_image.py:29: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# 2021-04-09 19:51:51.140681: W tensorflow/core/framework/op_def_util.cc:357] Op BatchNormWithGlobalNormalization is deprecated. It will cease to work in GraphDef version 9. Use tf.nn.batch_normalization().
# WARNING:tensorflow:From scripts/label_image.py:42: The name tf.read_file is deprecated. Please use tf.io.read_file instead.
#
# WARNING:tensorflow:From scripts/label_image.py:56: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# WARNING:tensorflow:From scripts/label_image.py:58: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-04-09 19:51:51.274020: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...
